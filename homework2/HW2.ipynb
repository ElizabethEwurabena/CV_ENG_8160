# %%
from utils import *
from models import *

# %%
#window=36, horizon=12
tobj_train = TrafficForecast(pkl_path='tps_df.pkl', window=36, horizon=12,type='train')
tobj_test = TrafficForecast(pkl_path='tps_df.pkl', window=36, horizon=12,type='test')
# Out:
# 1012680
# 253257

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
#1 x 36 x 2 hourxtrafficx
print(tobj_train.inputs[0].shape)
print(tobj_test.inputs[0].shape)
# Out:
# (1, 36, 2)
# (1, 36, 2)

# %%
bs = 300
dataloader_train = DataLoader(tobj_train, batch_size=bs, shuffle=False, num_workers=4,drop_last=True)
dataloader_test = DataLoader(tobj_test, batch_size=bs, shuffle=False, num_workers=4,drop_last=True)

# %%
for idx, data in enumerate(dataloader_train):
    print (data['inputs'].shape,data['outputs'].shape)
    if idx ==3:
        break
print('##########################')
for idx, data in enumerate(dataloader_test):
    print (data['inputs'].shape,data['outputs'].shape)
    if idx ==3:
        break
# Out:
# torch.Size([300, 36, 2]) torch.Size([300, 12])
# torch.Size([300, 36, 2]) torch.Size([300, 12])
# torch.Size([300, 36, 2]) torch.Size([300, 12])
# torch.Size([300, 36, 2]) torch.Size([300, 12])
# ##########################
# torch.Size([300, 36, 2]) torch.Size([300, 12])
# torch.Size([300, 36, 2]) torch.Size([300, 12])
# torch.Size([300, 36, 2]) torch.Size([300, 12])
# torch.Size([300, 36, 2]) torch.Size([300, 12])

# %%
from models import MyLSTM, MyGRU, MyRNN
LSTMmodel = MyLSTM(n_inputs=2, n_hidden=10, n_rnnlayers=2, n_outputs=12)
GRUmodel = MyGRU(n_inputs=2, n_hidden=10, n_rnnlayers=2, n_outputs=12)
RNNmodel = MyRNN(input_size=2, hidden_size=10, num_layers=2,output_size=12, bias=True)
RNNcell=MyRNNCell(input_size=2, hidden_size=10, bias=True)

# %% [markdown]
# train

# %%
#Train RNN
model=RNNmodel
model.to(device) 
epochs=100
train_val(model, epochs, dataloader_train, dataloader_test)
torch.save(model.state_dict(), 'rnn.pt')
# Out:
#   1%|          | 1/100 [00:21<35:13, 21.34s/it]
# Epoch 1/100, Training Loss: 0.0510, Testing Loss: 0.0015
#   2%|▏         | 2/100 [00:43<35:28, 21.72s/it]
# Epoch 2/100, Training Loss: 0.0082, Testing Loss: 0.0012
#   3%|▎         | 3/100 [01:04<35:00, 21.66s/it]
# Epoch 3/100, Training Loss: 0.0073, Testing Loss: 0.0012
#   4%|▍         | 4/100 [01:26<34:49, 21.77s/it]
# Epoch 4/100, Training Loss: 0.0072, Testing Loss: 0.0012
#   5%|▌         | 5/100 [01:49<34:53, 22.03s/it]
# Epoch 5/100, Training Loss: 0.0072, Testing Loss: 0.0013
#   6%|▌         | 6/100 [02:12<34:56, 22.30s/it]
# Epoch 6/100, Training Loss: 0.0071, Testing Loss: 0.0012
#   7%|▋         | 7/100 [02:34<34:36, 22.33s/it]
# Epoch 7/100, Training Loss: 0.0071, Testing Loss: 0.0012
#   8%|▊         | 8/100 [02:56<34:15, 22.34s/it]
# Epoch 8/100, Training Loss: 0.0071, Testing Loss: 0.0012
#   9%|▉         | 9/100 [03:20<34:17, 22.60s/it]
# Epoch 9/100, Training Loss: 0.0070, Testing Loss: 0.0012
# ...

# %%
#Train LSTM
model=LSTMmodel
epochs=100
model.to(device)
train_val(model, epochs, dataloader_train, dataloader_test)
torch.save(model.state_dict(), 'lstm.pt')
# Out:
#   1%|          | 1/100 [00:06<10:53,  6.60s/it]
# Epoch 1/100, Training Loss: 0.0296, Testing Loss: 0.0019
#   2%|▏         | 2/100 [00:13<11:09,  6.83s/it]
# Epoch 2/100, Training Loss: 0.0127, Testing Loss: 0.0018
#   3%|▎         | 3/100 [00:20<11:22,  7.03s/it]
# Epoch 3/100, Training Loss: 0.0097, Testing Loss: 0.0017
#   4%|▍         | 4/100 [00:28<11:22,  7.11s/it]
# Epoch 4/100, Training Loss: 0.0082, Testing Loss: 0.0016
#   5%|▌         | 5/100 [00:35<11:14,  7.10s/it]
# Epoch 5/100, Training Loss: 0.0079, Testing Loss: 0.0015
#   6%|▌         | 6/100 [00:42<11:15,  7.19s/it]
# Epoch 6/100, Training Loss: 0.0076, Testing Loss: 0.0015
#   7%|▋         | 7/100 [00:49<11:12,  7.23s/it]
# Epoch 7/100, Training Loss: 0.0074, Testing Loss: 0.0015
#   8%|▊         | 8/100 [00:57<11:25,  7.45s/it]
# Epoch 8/100, Training Loss: 0.0072, Testing Loss: 0.0014
#   9%|▉         | 9/100 [01:06<11:45,  7.76s/it]
# Epoch 9/100, Training Loss: 0.0070, Testing Loss: 0.0013
# ...

# %%
#train GRU
model=GRUmodel
epochs=100
model.to(device)
train_val(model, epochs, dataloader_train, dataloader_test)
torch.save(model.state_dict(), 'gru.pt')
# Out:
#   1%|          | 1/100 [00:06<10:17,  6.24s/it]
# Epoch 1/100, Training Loss: 0.0310, Testing Loss: 0.0017
#   2%|▏         | 2/100 [00:12<10:36,  6.49s/it]
# Epoch 2/100, Training Loss: 0.0128, Testing Loss: 0.0022
#   3%|▎         | 3/100 [00:19<10:34,  6.54s/it]
# Epoch 3/100, Training Loss: 0.0126, Testing Loss: 0.0022
#   4%|▍         | 4/100 [00:26<10:30,  6.57s/it]
# Epoch 4/100, Training Loss: 0.0118, Testing Loss: 0.0017
#   5%|▌         | 5/100 [00:32<10:27,  6.61s/it]
# Epoch 5/100, Training Loss: 0.0079, Testing Loss: 0.0015
#   6%|▌         | 6/100 [00:39<10:27,  6.67s/it]
# Epoch 6/100, Training Loss: 0.0075, Testing Loss: 0.0014
#   7%|▋         | 7/100 [00:46<10:27,  6.74s/it]
# Epoch 7/100, Training Loss: 0.0073, Testing Loss: 0.0015
#   8%|▊         | 8/100 [00:53<10:20,  6.74s/it]
# Epoch 8/100, Training Loss: 0.0072, Testing Loss: 0.0015
#   9%|▉         | 9/100 [01:00<10:19,  6.81s/it]
# Epoch 9/100, Training Loss: 0.0071, Testing Loss: 0.0015
# ...

# %%
LSTMmodel = MyLSTM(n_inputs=2, n_hidden=10, n_rnnlayers=2, n_outputs=12)
GRUmodel = MyGRU(n_inputs=2, n_hidden=10, n_rnnlayers=2, n_outputs=12)
RNNmodel = MyRNN(input_size=2, hidden_size=10, num_layers=2,output_size=12, bias=True)
RNNcell=MyRNNCell(input_size=2, hidden_size=10, bias=True)

# %% [markdown]
# predict

# %%
#predict dataloader
pred_obj= Predict(window=36, horizon=12)
bs = 87
dataloader_pred= DataLoader(pred_obj, batch_size=bs, shuffle=False, num_workers=4,drop_last=True)

for idx, data in enumerate(dataloader_pred):
    print (data['inputs'].shape)
    if idx ==3:
        break
# Out:
# 1305
# torch.Size([87, 36, 2])
# torch.Size([87, 36, 2])
# torch.Size([87, 36, 2])
# torch.Size([87, 36, 2])

# %%
#prediction using lstm
model = LSTMmodel
model_name ='lstm'
model_weight = 'lstm.pt'
predict_json(model, model_name, model_weight,dataloader_pred, device)
# Out:
#                  11     12     13     14     15     16     17     18     19  \
# 1.591078e+09  1.001  1.002  1.002  1.001  1.001  1.002  1.016  1.012  1.007
# 1.591079e+09  1.004  1.004  1.005  1.004  1.004  1.004  1.013  1.010  1.006
# 1.591080e+09  1.005  1.005  1.005  1.005  1.005  1.005  1.009  1.007  1.003
# 1.591081e+09  1.005  1.005  1.005  1.005  1.005  1.005  1.005  1.003  1.000
# 1.591082e+09  1.005  1.005  1.005  1.005  1.005  1.005  1.002  1.001  0.998
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1.592345e+09  0.847  0.924  0.955  0.933  0.966  0.975  0.975  0.976  0.986
# 1.592346e+09  0.844  0.922  0.952  0.930  0.963  0.972  0.972  0.972  0.983
# 1.592347e+09  0.845  0.922  0.951  0.929  0.961  0.970  0.971  0.971  0.982
# 1.592348e+09  0.851  0.925  0.952  0.930  0.961  0.970  0.971  0.971  0.982
# 1.592348e+09  0.861  0.931  0.955  0.933  0.964  0.972  0.972  0.972  0.983
#
# ...

# %%
#prediction using gru
model = GRUmodel
model_name ='gru'
model_weight = 'gru.pt'
predict_json(model, model_name, model_weight,dataloader_pred, device)
# Out:
#                  11     12     13     14     15     16     17     18     19  \
# 1.591078e+09  0.997  0.997  0.997  0.997  0.997  0.997  0.996  0.996  0.997
# 1.591079e+09  1.001  1.001  1.001  1.001  1.001  1.002  1.001  1.001  1.000
# 1.591080e+09  1.003  1.003  1.003  1.003  1.003  1.003  1.003  1.003  1.001
# 1.591081e+09  1.004  1.004  1.004  1.004  1.004  1.004  1.003  1.003  1.001
# 1.591082e+09  1.004  1.004  1.004  1.004  1.004  1.004  1.003  1.003  1.001
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1.592345e+09  0.890  0.962  0.970  0.941  0.966  0.973  0.973  0.973  0.984
# 1.592346e+09  0.889  0.963  0.972  0.941  0.967  0.974  0.974  0.974  0.985
# 1.592347e+09  0.892  0.967  0.976  0.944  0.970  0.978  0.978  0.978  0.988
# 1.592348e+09  0.898  0.973  0.981  0.950  0.976  0.983  0.983  0.983  0.992
# 1.592348e+09  0.906  0.979  0.987  0.957  0.981  0.988  0.988  0.988  0.996
#
# ...

# %%
#prediction using gru
model=RNNmodel
model_name ='rnn'
model_weight = 'rnn.pt'
predict_json(model, model_name, model_weight,dataloader_pred, device)
# Out:
#                  11     12     13     14     15     16     17     18     19  \
# 1.591078e+09  1.002  1.002  1.002  1.002  1.001  1.000  1.001  0.997  0.993
# 1.591079e+09  1.004  1.004  1.004  1.004  1.003  1.003  1.003  1.000  0.995
# 1.591080e+09  1.006  1.006  1.006  1.006  1.005  1.005  1.005  1.002  0.998
# 1.591081e+09  1.007  1.007  1.007  1.007  1.007  1.006  1.006  1.004  1.000
# 1.591082e+09  1.008  1.008  1.008  1.008  1.008  1.007  1.007  1.005  1.001
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1.592345e+09  0.961  0.975  0.979  0.974  0.979  0.982  0.982  0.982  0.982
# 1.592346e+09  0.959  0.973  0.979  0.972  0.979  0.982  0.982  0.982  0.982
# 1.592347e+09  0.958  0.973  0.978  0.972  0.978  0.981  0.981  0.981  0.981
# 1.592348e+09  0.957  0.972  0.977  0.971  0.977  0.981  0.981  0.981  0.981
# 1.592348e+09  0.956  0.971  0.977  0.970  0.977  0.980  0.980  0.980  0.980
#
# ...

# %% [markdown]
# different window

# %%
#window=36, horizon=36
tobj_train1 = TrafficForecast(pkl_path='tps_df.pkl', window=36, horizon=36,type='train')
tobj_test1 = TrafficForecast(pkl_path='tps_df.pkl', window=36, horizon=36,type='test')

bs = 300
dataloader_train1 = DataLoader(tobj_train1, batch_size=bs, shuffle=False, num_workers=4,drop_last=True)
dataloader_test1 = DataLoader(tobj_test1, batch_size=bs, shuffle=False, num_workers=4,drop_last=True)

for idx, data in enumerate(dataloader_train1):
    print (data['inputs'].shape,data['outputs'].shape)
    if idx ==3:
        break
print('##########################')
for idx, data in enumerate(dataloader_test1):
    print (data['inputs'].shape,data['outputs'].shape)
    if idx ==3:
        break
# Out:
# 1012680
# 253257
# torch.Size([300, 36, 2]) torch.Size([300, 36])
# torch.Size([300, 36, 2]) torch.Size([300, 36])
# torch.Size([300, 36, 2]) torch.Size([300, 36])
# torch.Size([300, 36, 2]) torch.Size([300, 36])
# ##########################
# torch.Size([300, 36, 2]) torch.Size([300, 36])
# torch.Size([300, 36, 2]) torch.Size([300, 36])
# torch.Size([300, 36, 2]) torch.Size([300, 36])
# torch.Size([300, 36, 2]) torch.Size([300, 36])

# %%
from models import MyLSTM, MyGRU, MyRNN
LSTMmodel1 = MyLSTM(n_inputs=2, n_hidden=10, n_rnnlayers=2, n_outputs=36)
GRUmodel1 = MyGRU(n_inputs=2, n_hidden=10, n_rnnlayers=2, n_outputs=36)
RNNmodel1 = MyRNN(input_size=2, hidden_size=10, num_layers=2,output_size=36, bias=True)
RNNcell1=MyRNNCell(input_size=2, hidden_size=10, bias=True)

# %%
#Train RNN
model=RNNmodel1
model.to(device) 
epochs=100
train_val(model, epochs, dataloader_train1, dataloader_test1)
torch.save(model.state_dict(), 'rnn1.pt')
# Out:
#   1%|          | 1/100 [00:21<35:47, 21.69s/it]
# Epoch 1/100, Training Loss: 0.0344, Testing Loss: 0.0016
#   2%|▏         | 2/100 [00:43<35:48, 21.92s/it]
# Epoch 2/100, Training Loss: 0.0111, Testing Loss: 0.0017
#   3%|▎         | 3/100 [01:05<35:24, 21.90s/it]
# Epoch 3/100, Training Loss: 0.0112, Testing Loss: 0.0017
#   4%|▍         | 4/100 [01:27<35:02, 21.90s/it]
# Epoch 4/100, Training Loss: 0.0110, Testing Loss: 0.0018
#   5%|▌         | 5/100 [01:49<34:36, 21.86s/it]
# Epoch 5/100, Training Loss: 0.0115, Testing Loss: 0.0020
#   6%|▌         | 6/100 [02:10<34:07, 21.78s/it]
# Epoch 6/100, Training Loss: 0.0115, Testing Loss: 0.0018
#   7%|▋         | 7/100 [02:33<33:54, 21.88s/it]
# Epoch 7/100, Training Loss: 0.0112, Testing Loss: 0.0018
#   8%|▊         | 8/100 [02:55<33:38, 21.94s/it]
# Epoch 8/100, Training Loss: 0.0110, Testing Loss: 0.0018
#   9%|▉         | 9/100 [03:17<33:18, 21.96s/it]
# Epoch 9/100, Training Loss: 0.0108, Testing Loss: 0.0020
# ...

# %%
#Train LSTM
model=LSTMmodel1
epochs=100
model.to(device)
train_val(model, epochs, dataloader_train1, dataloader_test1)
torch.save(model.state_dict(), 'lstm1.pt')
# Out:
#   1%|          | 1/100 [00:07<12:44,  7.73s/it]
# Epoch 1/100, Training Loss: 0.0294, Testing Loss: 0.0017
#   2%|▏         | 2/100 [00:15<12:31,  7.67s/it]
# Epoch 2/100, Training Loss: 0.0141, Testing Loss: 0.0017
#   3%|▎         | 3/100 [00:22<12:21,  7.65s/it]
# Epoch 3/100, Training Loss: 0.0137, Testing Loss: 0.0019
#   4%|▍         | 4/100 [00:30<12:14,  7.65s/it]
# Epoch 4/100, Training Loss: 0.0131, Testing Loss: 0.0018
#   5%|▌         | 5/100 [00:38<12:06,  7.65s/it]
# Epoch 5/100, Training Loss: 0.0121, Testing Loss: 0.0019
#   6%|▌         | 6/100 [00:45<11:55,  7.61s/it]
# Epoch 6/100, Training Loss: 0.0116, Testing Loss: 0.0019
#   7%|▋         | 7/100 [00:53<11:44,  7.57s/it]
# Epoch 7/100, Training Loss: 0.0114, Testing Loss: 0.0020
#   8%|▊         | 8/100 [01:00<11:30,  7.51s/it]
# Epoch 8/100, Training Loss: 0.0112, Testing Loss: 0.0020
#   9%|▉         | 9/100 [01:08<11:43,  7.73s/it]
# Epoch 9/100, Training Loss: 0.0111, Testing Loss: 0.0020
# ...

# %%
#train GRU
model=GRUmodel1
epochs=100
model.to(device)
train_val(model, epochs, dataloader_train1, dataloader_test1)
torch.save(model.state_dict(), 'gru1.pt')
# Out:
#   1%|          | 1/100 [00:07<11:59,  7.26s/it]
# Epoch 1/100, Training Loss: 0.0355, Testing Loss: 0.0016
#   2%|▏         | 2/100 [00:13<11:15,  6.90s/it]
# Epoch 2/100, Training Loss: 0.0135, Testing Loss: 0.0017
#   3%|▎         | 3/100 [00:20<10:53,  6.74s/it]
# Epoch 3/100, Training Loss: 0.0134, Testing Loss: 0.0017
#   4%|▍         | 4/100 [00:27<10:53,  6.81s/it]
# Epoch 4/100, Training Loss: 0.0133, Testing Loss: 0.0018
#   5%|▌         | 5/100 [00:34<10:48,  6.83s/it]
# Epoch 5/100, Training Loss: 0.0129, Testing Loss: 0.0020
#   6%|▌         | 6/100 [00:40<10:35,  6.76s/it]
# Epoch 6/100, Training Loss: 0.0127, Testing Loss: 0.0021
#   7%|▋         | 7/100 [00:47<10:28,  6.76s/it]
# Epoch 7/100, Training Loss: 0.0127, Testing Loss: 0.0021
#   8%|▊         | 8/100 [00:54<10:12,  6.66s/it]
# Epoch 8/100, Training Loss: 0.0126, Testing Loss: 0.0022
#   9%|▉         | 9/100 [01:00<10:11,  6.72s/it]
# Epoch 9/100, Training Loss: 0.0125, Testing Loss: 0.0022
# ...

# %% [markdown]
# Evaluation Comparisons

# %% [markdown]
# compare gru, lstm, rnn window=36 horizon=12

# %%
#lstm window of 36 and horizon of 12 
model = LSTMmodel
model.to(device)
model.load_state_dict(torch.load('lstm.pt'))
model.eval()
ev=evaluation(model, dataloader_test, device)
print(f"LSTM using both hour and traffic index, window of 36 and horizon of 12 gives: {ev}")
# Out:
# LSTM using both hour and traffic index, window of 36 and horizon of 12 gives: {'mae': 0.0151480045, 'mape': 0.017584011}

# %%
#lstm window of 36 and horizon of 36
model = LSTMmodel1
model.to(device)
model.load_state_dict(torch.load('lstm1.pt'))
model.eval()
ev=evaluation(model, dataloader_test1, device)
print(f"LSTM using both hour and traffic index, window of 36 and horizon of 36 gives: {ev}")
# Out:
# LSTM using both hour and traffic index, window of 36 and horizon of 36 gives: {'mae': 0.023136515, 'mape': 0.026047504}

# %%
#gru window of 36 and horizon of 12 
model = GRUmodel
model.to(device)
model.load_state_dict(torch.load('gru.pt'))
model.eval()
ev=evaluation(model, dataloader_test, device)
print(f"GRU using both hour and traffic index, window of 36 and horizon of 12 gives: {ev}")
# Out:
# GRU using both hour and traffic index, window of 36 and horizon of 12 gives: {'mae': 0.014314883, 'mape': 0.016873939}

# %%
#gru window of 36 and horizon of 36
model = GRUmodel1
model.to(device)
model.load_state_dict(torch.load('gru1.pt'))
model.eval()
ev=evaluation(model, dataloader_test1, device)
print(f"GRU using both hour and traffic index, window of 36 and horizon of 36 gives: {ev}")
# Out:
# GRU using both hour and traffic index, window of 36 and horizon of 36 gives: {'mae': 0.021654315, 'mape': 0.02458427}

# %%
#rnn window of 36 and horizon of 12 
model = RNNmodel
model.to(device)
model.load_state_dict(torch.load('rnn.pt'))
model.eval()
ev=evaluation(model, dataloader_test, device)
print(f"RNN using both hour and traffic index, window of 36 and horizon of 12 gives: {ev}")
# Out:
# RNN using both hour and traffic index, window of 36 and horizon of 12 gives: {'mae': 0.015104353, 'mape': 0.017689172}

# %%
#rnn window of 36 and horizon of 36
model = RNNmodel1
model.to(device)
model.load_state_dict(torch.load('rnn1.pt'))
model.eval()
ev=evaluation(model, dataloader_test1, device)
print(f"RNN using both hour and traffic index, window of 36 and horizon of 36 gives: {ev}")
# Out:
# RNN using both hour and traffic index, window of 36 and horizon of 36 gives: {'mae': 0.025158504, 'mape': 0.02806832}
